# %%
import h5py
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, callbacks
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.optimizers import SGD
from os import listdir
from os.path import isfile, join
from datetime import datetime
from os import listdir
from os.path import isfile, join

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_confusion_matrix
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix


# Importing custom framework
import sys, os
sys.path.insert(0, os.path.abspath('../..'))
from data_split import prepare_data_waveform

# %%
waveformPath = '../../merged/waveform.hdf5'

# %%
X_train, X_val, X_test, y_train, y_val, y_test = prepare_data_waveform(waveformPath, True)

# %% [markdown]
# <h2>Experiment 1</h2>

# %%
RF_model = RandomForestClassifier(min_samples_leaf=3, n_estimators=50, min_samples_split=10, max_features='sqrt', max_depth=6, random_state=0)
RF_model.fit(X_train, y_train)
print('train accuracy score: ')
print(RF_model.score(X_train, y_train))
print('validation accuracy score: ')
print(RF_model.score(X_val, y_val))
# Out:
# train accuracy score:
# 0.8174444444444444
# validation accuracy score:
# 0.7218333333333333

# %%
fig, ax = plt.subplots(figsize=(11, 11))
plot_confusion_matrix(RF_model, X_val, y_val, normalize='true', ax=ax)

# %% [markdown]
# <h2>Experiment 2</h2>

# %%
standard_model = RandomForestClassifier()
standard_model.fit(X_train, y_train)
print('train accuracy score: ')
print(standard_model.score(X_train, y_train))
print('validation accuracy score: ')
print(standard_model.score(X_val, y_val))
# Out:
# train accuracy score:
# 1.0
# validation accuracy score:
# 0.9035

# %%
fig, ax = plt.subplots(figsize=(11, 11))
plot_confusion_matrix(standard_model, X_val, y_val, normalize='true', ax=ax)

# %% [markdown]
# <h2>Experiment 3</h2>

# %%
model3 = RandomForestClassifier(n_estimators=120)
model3.fit(X_train, y_train)
print('train accuracy score: ')
print(model3.score(X_train, y_train))
print('validation accuracy score: ')
print(model3.score(X_val, y_val))
# Out:
# train accuracy score:
# 1.0
# validation accuracy score:
# 0.9048333333333334

# %%
print()
print('test accuracy score: ')
print(model3.score(X_test, y_test))
# Out:
# test accuracy score:
# 0.8996666666666666

# %%
confusion_matrix(y_val, model3.predict(X_val))
# Out:
# array([[573,   0,  15,   0,   3,   0,   5,   3,   0,   1],
#        [  0, 544,   9,   0,  14,   7,   0,   2,   0,  24],
#        [ 18,   0, 527,  27,   2,   0,   8,   2,  15,   1],
#        [  1,   0,  17, 565,   0,   1,   3,   2,  11,   0],
#        [  2,   5,   3,   0, 580,  10,   0,   0,   0,   0],
#        [  0,   7,   1,   2,  10, 538,   3,   6,   2,  31],
#        [  0,   0,   4,  18,   0,   4, 556,   2,  16,   0],
#        [ 17,   2,  13,  30,   2,  16,   5, 513,   1,   1],
#        [  0,   0,   1,  21,   0,   0,  12,   0, 566,   0],
#        [ 20,  32,  11,  38,   0,  18,   3,  11,   0, 467]])

# %%
fig, ax = plt.subplots(figsize=(11, 11))
plot_confusion_matrix(model3, X_val, y_val, normalize='true', ax=ax)
