# %%
from __future__ import absolute_import, division, print_function, unicode_literals

from tensorflow import keras
### hack tf-keras to appear as top level keras
import sys
sys.modules['keras'] = keras
### end of hack

import keras.backend as K
from keras.utils import multi_gpu_model
from keras.callbacks import TensorBoard

from sklearn.model_selection import KFold

import h5py
import numpy as np
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, callbacks
from keras.callbacks import *
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.optimizers import SGD
import numpy as np
import pprint
import os
from os import listdir
from os.path import isfile, join
from datetime import datetime

from tensorflow.keras.utils import plot_model

# Importing custom framework
import sys, os
sys.path.insert(0, os.path.abspath('../..'))
from data_split import prepare_data_spectrogram, return_generators

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
def build_cnn():
    model = models.Sequential()

    model.add(layers.Conv2D(227, (3, 1), activation='relu', input_shape=(227, 227, 1)))
    model.add(layers.MaxPooling2D((3, 1), 2))
    
    model.add(layers.Conv2D(64, (3, 1), activation='relu'))
    model.add(layers.MaxPooling2D((2, 1), 2))
    
    model.add(layers.Conv2D(128, (3, 1), activation='relu'))
    model.add(layers.MaxPooling2D((2, 1), 2))
    
    model.add(layers.Conv2D(128, (3, 1), activation='relu'))
    model.add(layers.MaxPooling2D((2, 1), 2))
    
    model.add(layers.Conv2D(128, (3, 1), activation='relu'))
    model.add(layers.MaxPooling2D((2, 1), 2))
    
    #Fully Connected Part
    model.add(layers.Flatten())
    
    model.add(layers.Dense(1024))#, input_dim=1024
    model.add(layers.Dropout(0.5, seed=1337))
    model.add(layers.Activation('relu'))
    
    model.add(layers.Dense(512))#, input_dim=1024
    model.add(layers.Dropout(0.5, seed=1337))
    model.add(layers.Activation('relu'))
    
    model.add(layers.Dense(10, input_dim=512))
    model.add(layers.Activation('softmax'))
    return model

# %%
spectrogramPath = '../../merged/spectrogram.hdf5'
#(train_generator, val_generator, test_generator) = return_generators(spectrogramPath)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_data_spectrogram(spectrogramPath, False, True)
print(X_train.shape)
X_train = tf.transpose(X_train, [0, 2, 3, 1])
X_val = tf.transpose(X_val, [0, 2, 3, 1])
X_test = tf.transpose(X_test, [0, 2, 3, 1])
# Out:
# (5000, 1, 227, 227)

# %%
import gc
gc.collect()
K.clear_session()
tf.compat.v1.reset_default_graph()

# %%
# Decrease training data size to make training feasable
#X_temp = []
#y_temp = []
#n = 300
#count_dict = dict.fromkeys(range(0, 10), 0)
#for i in range(len(y_train)):
#    curr = y_train[i]
#    if count_dict[curr] >= n:
#        finished = True
#        for x in count_dict.values():
#            if x < 300:
#                finished = False
#                break
#        if finished == True:
##            break
#    else:
#        count_dict[curr] = count_dict[curr] + 1
#        X_temp.append(X_train[i])
#        y_temp.append(curr)
        
#X_train = np.array(X_temp)
#y_train = np.array(y_temp)
#print(X_train.shape)

# %%
#tf.reset_default_graph()

tbCallBack = TensorBoard(log_dir='logs', histogram_freq=1,
                         write_graph=True,
                         write_grads=True,
                         write_images=True)

earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)

opt = SGD(lr=0.001, momentum=0.9, clipvalue=5)
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.

# %% [markdown]
# # Experiment 1

# %%
K.clear_session()
model = build_cnn()
#plot_model(model, to_file='CNN_Experiment1.png', show_shapes=True, show_layer_names=True)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

filepath = "logs/epochs:{epoch:03d}-val_acc:{val_acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

training_history = model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val),batch_size=32, callbacks=[earlyStopping, tbCallBack], shuffle=False)
# Generate generalization metrics
#scores = model.evaluate(X_val, y_val, verbose=0)
#print(f'Score {scores}')

    
#val_scores = model.evaluate(X_val, y_val, verbose=0)
#print(val_score)
# Out:
# Epoch 1/100
# 157/157 [==============================] - 397s 3s/step - loss: 2.3539 - accuracy: 0.1008 - val_loss: 2.3034 - val_accuracy: 0.0993
# Epoch 2/100
# 157/157 [==============================] - 397s 3s/step - loss: 2.3051 - accuracy: 0.1010 - val_loss: 2.3007 - val_accuracy: 0.1000
# Epoch 3/100
# 157/157 [==============================] - 397s 3s/step - loss: 2.3027 - accuracy: 0.1032 - val_loss: 2.3023 - val_accuracy: 0.0955
# Epoch 4/100
# 157/157 [==============================] - 397s 3s/step - loss: 2.3014 - accuracy: 0.1222 - val_loss: 2.3007 - val_accuracy: 0.1473
# Epoch 5/100
# 157/157 [==============================] - 398s 3s/step - loss: 2.2994 - accuracy: 0.1534 - val_loss: 2.2979 - val_accuracy: 0.2052
# Epoch 6/100
# 157/157 [==============================] - 396s 3s/step - loss: 2.2950 - accuracy: 0.1852 - val_loss: 2.2916 - val_accuracy: 0.2152
# Epoch 7/100
# 157/157 [==============================] - 397s 3s/step - loss: 2.2868 - accuracy: 0.1842 - val_loss: 2.2758 - val_accuracy: 0.2127
# Epoch 8/100
# 157/157 [==============================] - 396s 3s/step - loss: 2.2561 - accuracy: 0.1810 - val_loss: 2.2165 - val_accuracy: 0.1467
# Epoch 9/100
# 157/157 [==============================] - 397s 3s/step - loss: 2.1707 - accuracy: 0.2178 - val_loss: 2.0787 - val_accuracy: 0.2415
# Epoch 10/100
# 157/157 [==============================] - 397s 3s/step - loss: 1.9831 - accuracy: 0.3054 - val_loss: 1.8052 - val_accuracy: 0.3818
# Epoch 11/100
# 157/157 [==============================] - 396s 3s/step - loss: 1.7725 - accuracy: 0.3772 - val_loss: 1.5764 - val_accuracy: 0.4583
# Epoch 12/100
# 157/157 [==============================] - 398s 3s/step - loss: 1.5830 - accuracy: 0.4322 - val_loss: 1.6525 - val_accuracy: 0.4140
# Epoch 13/100
# 157/157 [==============================] - 397s 3s/step - loss: 1.4233 - accuracy: 0.4970 - val_loss: 1.4701 - val_accuracy: 0.4773
# Epoch 14/100
# 157/157 [==============================] - 397s 3s/step - loss: 1.3132 - accuracy: 0.5316 - val_loss: 1.3755 - val_accuracy: 0.5165
# Epoch 15/100
# 157/157 [==============================] - 396s 3s/step - loss: 1.1894 - accuracy: 0.5824 - val_loss: 1.2978 - val_accuracy: 0.5572
# Epoch 16/100
# 157/157 [==============================] - 397s 3s/step - loss: 1.0046 - accuracy: 0.6398 - val_loss: 1.2320 - val_accuracy: 0.5838
# Epoch 17/100
# 157/157 [==============================] - 398s 3s/step - loss: 0.8600 - accuracy: 0.6968 - val_loss: 1.0566 - val_accuracy: 0.6280
# Epoch 18/100
# 157/157 [==============================] - 397s 3s/step - loss: 0.7130 - accuracy: 0.7438 - val_loss: 1.1037 - val_accuracy: 0.6305
# Epoch 19/100
# 157/157 [==============================] - 398s 3s/step - loss: 0.5896 - accuracy: 0.7910 - val_loss: 1.0630 - val_accuracy: 0.6575
# Epoch 20/100
# 157/157 [==============================] - 398s 3s/step - loss: 0.5345 - accuracy: 0.8112 - val_loss: 1.0844 - val_accuracy: 0.6433
# Epoch 21/100
# 157/157 [==============================] - 396s 3s/step - loss: 0.4694 - accuracy: 0.8340 - val_loss: 1.1826 - val_accuracy: 0.6308
# Epoch 22/100
# 157/157 [==============================] - 396s 3s/step - loss: 0.3975 - accuracy: 0.8618 - val_loss: 1.0446 - val_accuracy: 0.6835
# Epoch 23/100
# 157/157 [==============================] - 398s 3s/step - loss: 0.3285 - accuracy: 0.8832 - val_loss: 1.0465 - val_accuracy: 0.6973
# Epoch 24/100
# 157/157 [==============================] - 396s 3s/step - loss: 0.3168 - accuracy: 0.8892 - val_loss: 1.0237 - val_accuracy: 0.6985
# Epoch 25/100
# 157/157 [==============================] - 396s 3s/step - loss: 0.2765 - accuracy: 0.9014 - val_loss: 1.0388 - val_accuracy: 0.7102
# Epoch 26/100
# 157/157 [==============================] - 396s 3s/step - loss: 0.2338 - accuracy: 0.9158 - val_loss: 1.3927 - val_accuracy: 0.6580
# Epoch 27/100
# 157/157 [==============================] - 397s 3s/step - loss: 0.2432 - accuracy: 0.9188 - val_loss: 1.0683 - val_accuracy: 0.6962
# Epoch 28/100
# 157/157 [==============================] - 397s 3s/step - loss: 0.2053 - accuracy: 0.9300 - val_loss: 1.0853 - val_accuracy: 0.7045

# %%
print(model.evaluate(X_test, y_test, verbose=0))
# Out:
# [0.8908129930496216, 0.7555000185966492]

# %%
validation_data=validation_generatortbCallBack = TensorBoard(log_dir='logs', histogram_freq=1,
                         write_graph=True,
                         write_grads=True,
                         write_images=True)

earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=8)

opt = SGD(lr=0.0001, momentum=0.9, clipvalue=5)
K.clear_session()
model = build_cnn()
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

filepath = "logs/epochs:{epoch:03d}-val_acc:{val_acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

training_history = model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val),batch_size=32, callbacks=[earlyStopping, tbCallBack], shuffle=False)
print(model.evaluate(X_test, y_test, verbose=0))
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# Epoch 1/100
# 157/157 [==============================] - 397s 3s/step - loss: 2.4155 - accuracy: 0.0962 - val_loss: 2.3015 - val_accuracy: 0.1148
# Epoch 2/100
# 157/157 [==============================] - 397s 3s/step - loss: 2.3079 - accuracy: 0.1132 - val_loss: 2.3012 - val_accuracy: 0.0978
# Epoch 3/100
# 157/157 [==============================] - 397s 3s/step - loss: 2.3125 - accuracy: 0.1006 - val_loss: 2.3033 - val_accuracy: 0.0882
# Epoch 4/100
# 157/157 [==============================] - 397s 3s/step - loss: 2.3093 - accuracy: 0.1072 - val_loss: 2.3006 - val_accuracy: 0.0983
# Epoch 5/100
# 157/157 [==============================] - 397s 3s/step - loss: 2.3066 - accuracy: 0.1026 - val_loss: 2.3010 - val_accuracy: 0.1220
# Epoch 6/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.3043 - accuracy: 0.1026 - val_loss: 2.3023 - val_accuracy: 0.1080
# Epoch 7/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.3034 - accuracy: 0.1064 - val_loss: 2.3010 - val_accuracy: 0.1120
# Epoch 8/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.3032 - accuracy: 0.1026 - val_loss: 2.3003 - val_accuracy: 0.1098
# Epoch 9/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.3008 - accuracy: 0.0984 - val_loss: 2.2976 - val_accuracy: 0.1452
# Epoch 10/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2983 - accuracy: 0.1146 - val_loss: 2.2994 - val_accuracy: 0.1143
# Epoch 11/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2980 - accuracy: 0.1102 - val_loss: 2.2950 - val_accuracy: 0.1427
# Epoch 12/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2954 - accuracy: 0.1188 - val_loss: 2.2935 - val_accuracy: 0.1482
# Epoch 13/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2945 - accuracy: 0.1108 - val_loss: 2.2917 - val_accuracy: 0.1295
# Epoch 14/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2919 - accuracy: 0.1234 - val_loss: 2.2881 - val_accuracy: 0.1562
# Epoch 15/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2887 - accuracy: 0.1210 - val_loss: 2.2859 - val_accuracy: 0.1532
# Epoch 16/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2872 - accuracy: 0.1216 - val_loss: 2.2806 - val_accuracy: 0.1430
# Epoch 17/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2828 - accuracy: 0.1304 - val_loss: 2.2760 - val_accuracy: 0.1313
# Epoch 18/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2792 - accuracy: 0.1326 - val_loss: 2.2704 - val_accuracy: 0.1443
# Epoch 19/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2753 - accuracy: 0.1248 - val_loss: 2.2641 - val_accuracy: 0.1430
# Epoch 20/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2725 - accuracy: 0.1322 - val_loss: 2.2566 - val_accuracy: 0.1335
# Epoch 21/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2611 - accuracy: 0.1314 - val_loss: 2.2472 - val_accuracy: 0.1320
# Epoch 22/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2496 - accuracy: 0.1426 - val_loss: 2.2353 - val_accuracy: 0.1418
# Epoch 23/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2428 - accuracy: 0.1402 - val_loss: 2.2249 - val_accuracy: 0.1407
# Epoch 24/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2336 - accuracy: 0.1484 - val_loss: 2.2116 - val_accuracy: 0.1475
# Epoch 25/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.2243 - accuracy: 0.1512 - val_loss: 2.1978 - val_accuracy: 0.1537
# Epoch 26/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.2099 - accuracy: 0.1552 - val_loss: 2.1826 - val_accuracy: 0.1617
# Epoch 27/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.1978 - accuracy: 0.1660 - val_loss: 2.1666 - val_accuracy: 0.1703
# Epoch 28/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.1847 - accuracy: 0.1814 - val_loss: 2.1457 - val_accuracy: 0.1945
# Epoch 29/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.1698 - accuracy: 0.1908 - val_loss: 2.1339 - val_accuracy: 0.2032
# Epoch 30/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.1441 - accuracy: 0.2122 - val_loss: 2.0921 - val_accuracy: 0.2497
# Epoch 31/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.1270 - accuracy: 0.2240 - val_loss: 2.0570 - val_accuracy: 0.2988
# Epoch 32/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.0946 - accuracy: 0.2600 - val_loss: 2.0182 - val_accuracy: 0.3262
# Epoch 33/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.0679 - accuracy: 0.2708 - val_loss: 1.9662 - val_accuracy: 0.3657
# Epoch 34/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.0373 - accuracy: 0.2910 - val_loss: 1.9313 - val_accuracy: 0.3615
# Epoch 35/100
# 157/157 [==============================] - 401s 3s/step - loss: 1.9889 - accuracy: 0.3046 - val_loss: 1.8419 - val_accuracy: 0.4003
# Epoch 36/100
# 157/157 [==============================] - 401s 3s/step - loss: 1.9511 - accuracy: 0.3160 - val_loss: 1.8379 - val_accuracy: 0.3687
# Epoch 37/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.9020 - accuracy: 0.3392 - val_loss: 1.7587 - val_accuracy: 0.4120
# Epoch 38/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.8800 - accuracy: 0.3396 - val_loss: 1.7155 - val_accuracy: 0.4272
# Epoch 39/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.8226 - accuracy: 0.3692 - val_loss: 1.6695 - val_accuracy: 0.4387
# Epoch 40/100
# 157/157 [==============================] - 401s 3s/step - loss: 1.7615 - accuracy: 0.3816 - val_loss: 1.5985 - val_accuracy: 0.4743
# Epoch 41/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.7382 - accuracy: 0.3910 - val_loss: 1.5483 - val_accuracy: 0.5063
# Epoch 42/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.6915 - accuracy: 0.4114 - val_loss: 1.5591 - val_accuracy: 0.4778
# Epoch 43/100
# 157/157 [==============================] - 401s 3s/step - loss: 1.6573 - accuracy: 0.4192 - val_loss: 1.4955 - val_accuracy: 0.5012
# Epoch 44/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.6017 - accuracy: 0.4396 - val_loss: 1.4222 - val_accuracy: 0.5225
# Epoch 45/100
# 157/157 [==============================] - 401s 3s/step - loss: 1.5329 - accuracy: 0.4656 - val_loss: 1.3730 - val_accuracy: 0.5415
# Epoch 46/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.5149 - accuracy: 0.4712 - val_loss: 1.3658 - val_accuracy: 0.5370
# Epoch 47/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.4893 - accuracy: 0.4772 - val_loss: 1.3566 - val_accuracy: 0.5340
# Epoch 48/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.4503 - accuracy: 0.4892 - val_loss: 1.3348 - val_accuracy: 0.5407
# Epoch 49/100
# 157/157 [==============================] - 401s 3s/step - loss: 1.3983 - accuracy: 0.5042 - val_loss: 1.2737 - val_accuracy: 0.5685
# Epoch 50/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.3406 - accuracy: 0.5284 - val_loss: 1.2429 - val_accuracy: 0.5770
# Epoch 51/100
# 157/157 [==============================] - 401s 3s/step - loss: 1.3089 - accuracy: 0.5410 - val_loss: 1.2093 - val_accuracy: 0.5953
# Epoch 52/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.2673 - accuracy: 0.5574 - val_loss: 1.3823 - val_accuracy: 0.5045
# Epoch 53/100
# 157/157 [==============================] - 401s 3s/step - loss: 1.2305 - accuracy: 0.5812 - val_loss: 1.1515 - val_accuracy: 0.6097
# Epoch 54/100
# 157/157 [==============================] - 401s 3s/step - loss: 1.1891 - accuracy: 0.5826 - val_loss: 1.1470 - val_accuracy: 0.6090
# Epoch 55/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.1588 - accuracy: 0.5990 - val_loss: 1.2281 - val_accuracy: 0.5722
# Epoch 56/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.1057 - accuracy: 0.6104 - val_loss: 1.1020 - val_accuracy: 0.6188
# Epoch 57/100
# 157/157 [==============================] - 399s 3s/step - loss: 1.0734 - accuracy: 0.6302 - val_loss: 1.1070 - val_accuracy: 0.6135
# Epoch 58/100
# 157/157 [==============================] - 401s 3s/step - loss: 1.0195 - accuracy: 0.6506 - val_loss: 1.1190 - val_accuracy: 0.6090
# Epoch 59/100
# 157/157 [==============================] - 400s 3s/step - loss: 1.0130 - accuracy: 0.6522 - val_loss: 1.0407 - val_accuracy: 0.6410
# Epoch 60/100
# 157/157 [==============================] - 400s 3s/step - loss: 0.9675 - accuracy: 0.6690 - val_loss: 1.1093 - val_accuracy: 0.6168
# Epoch 61/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.9219 - accuracy: 0.6882 - val_loss: 0.9804 - val_accuracy: 0.6600
# Epoch 62/100
# 157/157 [==============================] - 400s 3s/step - loss: 0.8993 - accuracy: 0.6918 - val_loss: 0.9677 - val_accuracy: 0.6652
# Epoch 63/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.8526 - accuracy: 0.7066 - val_loss: 0.9782 - val_accuracy: 0.6555
# Epoch 64/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.8136 - accuracy: 0.7228 - val_loss: 0.9099 - val_accuracy: 0.6808
# Epoch 65/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.7625 - accuracy: 0.7492 - val_loss: 0.8991 - val_accuracy: 0.6865
# Epoch 66/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.7482 - accuracy: 0.7410 - val_loss: 0.8623 - val_accuracy: 0.6987
# Epoch 67/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.7259 - accuracy: 0.7558 - val_loss: 0.9339 - val_accuracy: 0.6763
# Epoch 68/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.6979 - accuracy: 0.7620 - val_loss: 0.8698 - val_accuracy: 0.6970
# Epoch 69/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.6667 - accuracy: 0.7678 - val_loss: 0.8848 - val_accuracy: 0.6875
# Epoch 70/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.6287 - accuracy: 0.7894 - val_loss: 0.9167 - val_accuracy: 0.6857
# Epoch 71/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.6287 - accuracy: 0.7854 - val_loss: 0.8587 - val_accuracy: 0.7005
# Epoch 72/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.5874 - accuracy: 0.7980 - val_loss: 1.0200 - val_accuracy: 0.6645
# Epoch 73/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.5858 - accuracy: 0.7936 - val_loss: 0.8659 - val_accuracy: 0.7047
# Epoch 74/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.5627 - accuracy: 0.8078 - val_loss: 0.9858 - val_accuracy: 0.6713
# Epoch 75/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.5518 - accuracy: 0.8106 - val_loss: 0.8367 - val_accuracy: 0.7132
# Epoch 76/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.5242 - accuracy: 0.8254 - val_loss: 0.7717 - val_accuracy: 0.7343
# Epoch 77/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.4883 - accuracy: 0.8328 - val_loss: 0.7974 - val_accuracy: 0.7247
# Epoch 78/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.4806 - accuracy: 0.8358 - val_loss: 0.7637 - val_accuracy: 0.7380
# Epoch 79/100
# 157/157 [==============================] - 403s 3s/step - loss: 0.4620 - accuracy: 0.8408 - val_loss: 0.7982 - val_accuracy: 0.7263
# Epoch 80/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.4426 - accuracy: 0.8490 - val_loss: 0.7855 - val_accuracy: 0.7350
# Epoch 81/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.4368 - accuracy: 0.8496 - val_loss: 0.7828 - val_accuracy: 0.7345
# Epoch 82/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.4385 - accuracy: 0.8564 - val_loss: 0.7564 - val_accuracy: 0.7420
# Epoch 83/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.4228 - accuracy: 0.8566 - val_loss: 0.7785 - val_accuracy: 0.7328
# Epoch 84/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.3970 - accuracy: 0.8596 - val_loss: 0.7841 - val_accuracy: 0.7387
# Epoch 85/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.3823 - accuracy: 0.8756 - val_loss: 0.7761 - val_accuracy: 0.7413
# Epoch 86/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.3838 - accuracy: 0.8706 - val_loss: 0.7384 - val_accuracy: 0.7477
# Epoch 87/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.3771 - accuracy: 0.8726 - val_loss: 0.7890 - val_accuracy: 0.7370
# Epoch 88/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.3500 - accuracy: 0.8762 - val_loss: 0.7738 - val_accuracy: 0.7358
# Epoch 89/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.3370 - accuracy: 0.8832 - val_loss: 0.7654 - val_accuracy: 0.7450
# Epoch 90/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.3300 - accuracy: 0.8882 - val_loss: 0.7336 - val_accuracy: 0.7545
# Epoch 91/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.3072 - accuracy: 0.8940 - val_loss: 0.7939 - val_accuracy: 0.7430
# Epoch 92/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.3048 - accuracy: 0.9018 - val_loss: 0.7708 - val_accuracy: 0.7458
# Epoch 93/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.2868 - accuracy: 0.9024 - val_loss: 0.7904 - val_accuracy: 0.7428
# Epoch 94/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.2848 - accuracy: 0.9020 - val_loss: 0.7921 - val_accuracy: 0.7482
# Epoch 95/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.2693 - accuracy: 0.9046 - val_loss: 0.8134 - val_accuracy: 0.7460
# Epoch 96/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.2599 - accuracy: 0.9106 - val_loss: 0.7741 - val_accuracy: 0.7518
# Epoch 97/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.2627 - accuracy: 0.9106 - val_loss: 0.7776 - val_accuracy: 0.7560
# Epoch 98/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.2649 - accuracy: 0.9132 - val_loss: 0.8158 - val_accuracy: 0.7438
# [0.6240507960319519, 0.7925000190734863]

# %%
tbCallBack = TensorBoard(log_dir='logs', histogram_freq=1,
                         write_graph=True,
                         write_grads=True,
                         write_images=True)

earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=8)

opt = keras.optimizers.Adam(learning_rate=0.001)
K.clear_session()
model = build_cnn()
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

filepath = "logs/Ex3Epochs:{epoch:03d}-val_acc:{val_acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

training_history = model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val),batch_size=32, callbacks=[earlyStopping, tbCallBack], shuffle=False)
print(model.evaluate(X_test, y_test, verbose=0))
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# Epoch 1/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3598 - accuracy: 0.1098 - val_loss: 2.3037 - val_accuracy: 0.1000
# Epoch 2/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.3078 - accuracy: 0.1040 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 3/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3039 - accuracy: 0.0996 - val_loss: 2.3026 - val_accuracy: 0.1002
# Epoch 4/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.3032 - accuracy: 0.0978 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 5/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3034 - accuracy: 0.0976 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 6/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.3037 - accuracy: 0.1056 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 7/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.3036 - accuracy: 0.0936 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 8/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.3031 - accuracy: 0.0976 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 9/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.3036 - accuracy: 0.0954 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 10/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3029 - accuracy: 0.1054 - val_loss: 2.3026 - val_accuracy: 0.1002
# Epoch 11/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.3036 - accuracy: 0.0990 - val_loss: 2.3026 - val_accuracy: 0.0998
# Epoch 12/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.3037 - accuracy: 0.1012 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 13/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3032 - accuracy: 0.0926 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 14/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.3032 - accuracy: 0.0930 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 15/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.3030 - accuracy: 0.1024 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 16/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.3029 - accuracy: 0.1008 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 17/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3030 - accuracy: 0.1018 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 18/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.3032 - accuracy: 0.0992 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 19/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3033 - accuracy: 0.0952 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 20/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3031 - accuracy: 0.0994 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 21/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3032 - accuracy: 0.1010 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 22/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3028 - accuracy: 0.1026 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 23/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3029 - accuracy: 0.1056 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 24/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.3029 - accuracy: 0.1066 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 25/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.3032 - accuracy: 0.0978 - val_loss: 2.3026 - val_accuracy: 0.1000
# [2.302600383758545, 0.10000000149011612]

# %%
tbCallBack = TensorBoard(log_dir='logs', histogram_freq=1,
                         write_graph=True,
                         write_grads=True,
                         write_images=True)

earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4)

opt = keras.optimizers.Adam(learning_rate=0.0001)
K.clear_session()
model = build_cnn()
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

filepath = "logs/Ex4Epochs:{epoch:03d}-val_acc:{val_acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

training_history = model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val),batch_size=32, callbacks=[earlyStopping, tbCallBack], shuffle=False)
print(model.evaluate(X_test, y_test, verbose=0))
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# Epoch 1/100
# 157/157 [==============================] - 402s 3s/step - loss: 2.4040 - accuracy: 0.1090 - val_loss: 2.2775 - val_accuracy: 0.1782
# Epoch 2/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.1902 - accuracy: 0.1804 - val_loss: 1.7874 - val_accuracy: 0.4177
# Epoch 3/100
# 157/157 [==============================] - 402s 3s/step - loss: 1.6680 - accuracy: 0.3954 - val_loss: 1.2414 - val_accuracy: 0.5882
# Epoch 4/100
# 157/157 [==============================] - 401s 3s/step - loss: 1.1127 - accuracy: 0.6128 - val_loss: 0.8821 - val_accuracy: 0.7018
# Epoch 5/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.7389 - accuracy: 0.7472 - val_loss: 0.9031 - val_accuracy: 0.6908
# Epoch 6/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.4852 - accuracy: 0.8432 - val_loss: 0.8932 - val_accuracy: 0.7130
# Epoch 7/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.3247 - accuracy: 0.8886 - val_loss: 0.7213 - val_accuracy: 0.7672
# Epoch 8/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.2490 - accuracy: 0.9190 - val_loss: 0.9050 - val_accuracy: 0.7377
# Epoch 9/100
# 157/157 [==============================] - 401s 3s/step - loss: 0.2144 - accuracy: 0.9264 - val_loss: 0.8539 - val_accuracy: 0.7430
# Epoch 10/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.1657 - accuracy: 0.9452 - val_loss: 0.9260 - val_accuracy: 0.7582
# Epoch 11/100
# 157/157 [==============================] - 402s 3s/step - loss: 0.1588 - accuracy: 0.9452 - val_loss: 0.7776 - val_accuracy: 0.7890
# [0.5561389327049255, 0.8324999809265137]

# %%
tbCallBack = TensorBoard(log_dir='logs', histogram_freq=1,
                         write_graph=True,
                         write_grads=True,
                         write_images=True)

earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4)

opt = keras.optimizers.Adam(learning_rate=0.01)
K.clear_session()
model = build_cnn()
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

filepath = "logs/Ex5Epochs:{epoch:03d}-val_acc:{val_acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

training_history = model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val),batch_size=32, callbacks=[earlyStopping, tbCallBack], shuffle=False)
print(model.evaluate(X_test, y_test, verbose=0))
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# Epoch 1/100
# 157/157 [==============================] - 400s 3s/step - loss: 4.8675 - accuracy: 0.0928 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 2/100
# 157/157 [==============================] - 400s 3s/step - loss: 2.3052 - accuracy: 0.0860 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/100
# 157/157 [==============================] - 399s 3s/step - loss: 2.3038 - accuracy: 0.0918 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 4/100
# 157/157 [==============================] - 399s 3s/step - loss: 2.3036 - accuracy: 0.0950 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 5/100
# 157/157 [==============================] - 399s 3s/step - loss: 2.3040 - accuracy: 0.0882 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 6/100
# 157/157 [==============================] - 399s 3s/step - loss: 2.3036 - accuracy: 0.0894 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 7/100
# 157/157 [==============================] - 401s 3s/step - loss: 2.3039 - accuracy: 0.0866 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 8/100
# 157/157 [==============================] - 399s 3s/step - loss: 2.3038 - accuracy: 0.0876 - val_loss: 2.3026 - val_accuracy: 0.1000
# [2.302610158920288, 0.10000000149011612]
